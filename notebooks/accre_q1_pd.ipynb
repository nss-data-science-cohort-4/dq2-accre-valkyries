# %% [markdown]
# Question #1
# Use data to see if there are any clusters of job failures on specific nodes. Determine whether any of the production partition nodes show an unusual number of failed jobs relative to the others. Ignore the debug partition.
#
# Action:
# 1) clean up df columns to only reflect relevant columns
# 2) Determine any pattern of job failures for specific nodes
# 3) Analyze Exit codes 0:0, discard the user errors for this item?
# 4) Review number of jobs that have 1 node to first see if there is a pattern
# 5) NTH: Determine whether pattern of failure rate as job ids increase
# 6) NTH: Determine whether pattern of failure rate for jobs with >1 node (e.g., communication failure between certain nodes (any correlations between nodes, clusters, hardware, etc)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
# %matplotlib inline
from io import StringIO
import re

# %%
for_pd = StringIO()
with open('../data/accre-jobs-2020.csv') as accre:
    for line in accre:
        new_line = re.sub(r',', '|', line.rstrip(), count=12)
        print (new_line, file=for_pd)

for_pd.seek(0)

accre = pd.read_csv(for_pd, sep='|')
print (accre)
# Out:
#                JOBID        ACCOUNT       USER    REQMEM    USEDMEM  \
# 0           15925210        treviso   arabella  122880Mn  65973.49M
# 1           15861126        treviso   arabella  122880Mn  67181.12M
# 2           15861125        treviso   arabella  122880Mn  69111.86M
# 3           16251645        treviso   arabella  122880Mn  65317.33M
# 4           16251646        treviso   arabella  122880Mn  65876.11M
# ...              ...            ...        ...       ...        ...
# 3816285   24173815_8     portabella     vennie   32768Mn  30042.68M
# 3816286   24173815_9     portabella     vennie   32768Mn  31067.75M
# 3816287  24173815_10     portabella     vennie   32768Mn  21207.96M
# 3816288     24173817  boysenberries  hortensia  100000Mn          0
# 3816289     24173866    horseradish     ariane   20480Mn          0
#
#              REQTIME     USEDTIME  NODES  CPUS   PARTITION EXITCODE  \
# 0        13-18:00:00  13-18:00:28      1    24  production      0:0
# 1        13-18:00:00  12-14:50:56      1    24  production      0:0
# 2        13-18:00:00  13-18:00:20      1    24  production      0:0
# 3        13-18:00:00  12-03:50:32      1    24  production      0:0
# 4        13-18:00:00  13-18:00:03      1    24  production      0:0
# ...              ...          ...    ...   ...         ...      ...
# 3816285   1-00:00:00     00:02:27      1     2  production      0:0
# 3816286   1-00:00:00     00:02:27      1     2  production      0:0
# 3816287   1-00:00:00     00:01:40      1     2  production      0:0
# 3816288   1-00:00:00     00:03:05      1     8  production      0:0
# 3816289     05:00:00     00:02:05      1     1  production      0:0
#
#              STATE NODELIST
# 0        COMPLETED   cn1531
# 1        COMPLETED   cn1441
# 2        COMPLETED   cn1464
# 3        COMPLETED   cn1473
# 4        COMPLETED   cn1440
# ...            ...      ...
# 3816285  COMPLETED    cn312
# 3816286  COMPLETED    cn312
# 3816287  COMPLETED    cn368
# 3816288    RUNNING   cn1509
# 3816289    RUNNING   cn1131
#
# [3816290 rows x 13 columns]

# %%
accre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3816290 entries, 0 to 3816289
# Data columns (total 13 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   JOBID      object
#  1   ACCOUNT    object
#  2   USER       object
#  3   REQMEM     object
#  4   USEDMEM    object
#  5   REQTIME    object
#  6   USEDTIME   object
#  7   NODES      int64
#  8   CPUS       int64
#  9   PARTITION  object
#  10  EXITCODE   object
#  11  STATE      object
#  12  NODELIST   object
# dtypes: int64(2), object(11)
# memory usage: 378.5+ MB

# %%
accre.EXITCODE.describe()
# Out:
# count     3816290
# unique         30
# top           0:0
# freq      3813403
# Name: EXITCODE, dtype: object

# %%
accre.EXITCODE.unique()
# Out:
# array(['0:0', '0:6', '0:15', '1:0', '126:0', '0:9', '2:0', '0:125',
#        '13:0', '127:0', '8:0', '6:0', '0:39', '0:105', '7:0', '116:0',
#        '0:4', '0:7', '0:12', '101:0', '24:0', '38:0', '99:0', '11:0',
#        '0:36', '0:11', '64:0', '0:2', '16:0', '59:0'], dtype=object)

# %%
accre.STATE.unique()
# Out:
# array(['COMPLETED', 'CANCELLED', 'FAILED', 'OUT_OF_MEMORY',
#        'CANCELLED by 782611', 'CANCELLED by 791651', 'CANCELLED by 9206',
#        'CANCELLED by 785271', 'CANCELLED by 666860',
#        'CANCELLED by 686562', 'CANCELLED by 397600',
#        'CANCELLED by 199066', 'CANCELLED by 503585',
#        'CANCELLED by 505355', 'TIMEOUT', 'CANCELLED by 486541',
#        'CANCELLED by 763605', 'CANCELLED by 124006', 'CANCELLED by 90423',
#        'CANCELLED by 200557', 'CANCELLED by 649319',
#        'CANCELLED by 483348', 'CANCELLED by 855431',
#        'CANCELLED by 199766', 'CANCELLED by 337422', 'CANCELLED by 0',
#        'CANCELLED by 546080', 'CANCELLED by 693461',
#        'CANCELLED by 782535', 'CANCELLED by 515423',
#        'CANCELLED by 454080', 'CANCELLED by 9201', 'CANCELLED by 649321',
#        'CANCELLED by 9202', 'CANCELLED by 895426', 'CANCELLED by 651701',
#        'CANCELLED by 781109', 'RUNNING'], dtype=object)

# %%
accre.STATE.describe()
# Out:
# count       3816290
# unique           38
# top       COMPLETED
# freq        3804644
# Name: STATE, dtype: object

# %%
accre.groupby('STATE').size()
# Out:
# STATE
# CANCELLED                 6107
# CANCELLED by 0               5
# CANCELLED by 124006          2
# CANCELLED by 199066          2
# CANCELLED by 199766          4
# CANCELLED by 200557          6
# CANCELLED by 337422          1
# CANCELLED by 397600          7
# CANCELLED by 454080          4
# CANCELLED by 483348          3
# CANCELLED by 486541          4
# CANCELLED by 503585          1
# CANCELLED by 505355         63
# CANCELLED by 515423          2
# CANCELLED by 546080          2
# CANCELLED by 649319          3
# CANCELLED by 649321          1
# CANCELLED by 651701          1
# CANCELLED by 666860          2
# CANCELLED by 686562        681
# CANCELLED by 693461          2
# CANCELLED by 763605          1
# CANCELLED by 781109          1
# CANCELLED by 782535          1
# CANCELLED by 782611         13
# CANCELLED by 785271          1
# CANCELLED by 791651          2
# CANCELLED by 855431         17
# CANCELLED by 895426          2
# CANCELLED by 90423           2
# CANCELLED by 9201            3
# CANCELLED by 9202            3
# CANCELLED by 9206            9
# COMPLETED              3804644
# FAILED                    1406
# OUT_OF_MEMORY               94
# RUNNING                   3108
# TIMEOUT                     80
# dtype: int64

# %%
# review failed nodes, first identify failed jobs
failed_jobs = accre[accre['STATE'] == 'FAILED']
failed_jobs
# Out:
#             JOBID      ACCOUNT        USER    REQMEM    USEDMEM     REQTIME  \
# 8629     17094238          cms    cmspilot  186648Mn      1.78M  2-00:00:00
# 8632     17094335          cms    cmspilot  186648Mn      8.38M  2-00:00:00
# 22234    17072678          cms    cmspilot   21875Mn  11310.72M  2-00:00:00
# 56716    17150413  blueberries        leva    4096Mn   1968.02M    10:00:00
# 68661    17178412    cubanelle       robyn    1024Mc     73.32M    00:15:00
# ...           ...          ...         ...       ...        ...         ...
# 3813639  24168919       pinole       daryl  376832Mn     11.52M    00:30:00
# 3814389  24170236      alkmene     abigail    8192Mn      5.81M    02:00:00
# 3814493  24170522      alkmene     abigail    8192Mn      5.81M    02:00:00
# 3814510  24170592       pinole       daryl  380280Mn      6.10M    00:30:00
# 3816160  24173530          cms  uscmslocal   21878Mn  18923.71M  2-00:00:00
#
#          USEDTIME  NODES  CPUS   PARTITION EXITCODE   STATE       NODELIST
# 8629     00:01:11      1     0      nogpfs      1:0  FAILED         cn1554
# 8632     00:01:26      1     0      nogpfs      1:0  FAILED         cn1544
# 22234    00:02:35      1     8      nogpfs    126:0  FAILED          ng909
# 56716    02:15:54      1     1      pascal      1:0  FAILED        gpu0021
# 68661    00:14:17      1     1      pascal      2:0  FAILED        gpu0021
# ...           ...    ...   ...         ...      ...     ...            ...
# 3813639  00:01:28      1     1      turing      1:0  FAILED        gpu0048
# 3814389  00:08:07      2     8  production      1:0  FAILED  cn[1123,1128]
# 3814493  00:08:42      2     8  production      1:0  FAILED  cn[1207,1455]
# 3814510  00:02:25      1     1      turing    126:0  FAILED        gpu0045
# 3816160  00:20:12      1     8      nogpfs      0:0  FAILED          ng743
#
# [1406 rows x 13 columns]

# %%
accre.PARTITION.describe()
# Out:
# count        3816290
# unique            15
# top       production
# freq         3311788
# Name: PARTITION, dtype: object

# %%
accre.PARTITION.unique()
# Out:
# array(['production', 'cgw-dougherty1', 'cgw-capra1', 'cgw-cqs1', 'pascal',
#        'turing', 'cgw-tbi01', 'nogpfs', 'maxwell', 'sam', 'debug',
#        'devel', 'cgw-cqs3', 'cgw-rocksteady', 'cgw-vm-qa-flatearth1'],
#       dtype=object)

# %%
#failed_2 = accre[(accre["STATE"] == 'FAILED') & (accre['PARTITION'] != 'debug')] #| (accre['PARTITION'] != 'debug') |(accre['PARTITION'] != 'turing')]
#failed_2

# %%
# failed_3 = accre[(accre["STATE"] == 'FAILED') & (accre['PARTITION'] == 'cgw-rocksteady')] 
# failed_3

# %% [markdown]
# I set up a df called "failed" which took the entire accre df and filtered to State = Failed, and Partition = Production.  This is due to the slides 37 (ignore debug, pascal, turing, maxwell), and by filtering found that only production partition has failed jobs.

# %%
failed = accre[(accre["STATE"] == 'FAILED') & (accre['PARTITION'] == 'production')]
failed.head()
# Out:
#            JOBID ACCOUNT    USER   REQMEM   USEDMEM     REQTIME    USEDTIME  \
# 104031  17234446  crowns    tena   5120Mc  8737.88M  1-12:00:00  1-12:00:12
# 124397  17261993   burro   golda   1024Mc         0    00:30:00    00:00:01
# 167790  17329248   pearl  auther   1024Mc         0    00:30:00    00:00:00
# 199503  17354412  crowns    tena   5120Mc  4277.54M  1-06:00:00    01:49:02
# 226420  17390284    bulk    lela  20480Mn  4028.41M    20:00:00    00:01:01
#
#         NODES  CPUS   PARTITION EXITCODE   STATE  \
# 104031     51     1  production      1:0  FAILED
# 124397      1     1  production     13:0  FAILED
# 167790      2     8  production      2:0  FAILED
# 199503     75     1  production      1:0  FAILED
# 226420     10     1  production      1:0  FAILED
#
#                                                  NODELIST
# 104031  cn[336-338,340,347-348,374-380,386-396,401,403...
# 124397                                              cn394
# 167790                                        cn[326,499]
# 199503  cn[331-338,340,347-349,361-367,386-393,395-396...
# 226420  cn[1263,1275,1303,1309,1335-1336,1351,1372,137...

# %%
failed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 104031 to 3814493
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   JOBID      500 non-null    object
#  1   ACCOUNT    500 non-null    object
#  2   USER       500 non-null    object
#  3   REQMEM     500 non-null    object
#  4   USEDMEM    500 non-null    object
#  5   REQTIME    500 non-null    object
#  6   USEDTIME   500 non-null    object
#  7   NODES      500 non-null    int64
#  8   CPUS       500 non-null    int64
#  9   PARTITION  500 non-null    object
#  10  EXITCODE   500 non-null    object
#  11  STATE      500 non-null    object
#  12  NODELIST   500 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 54.7+ KB

# %%
failed.NODELIST.unique()
# Out:
# array(['cn[336-338,340,347-348,374-380,386-396,401,403-405,407-411,487-500,911-913,1081]',
#        'cn394', 'cn[326,499]',
#        'cn[331-338,340,347-349,361-367,386-393,395-396,398-401,403-405,407-414,441-448,464-473,1273-1279,1340-1345]',
#        'cn[1263,1275,1303,1309,1335-1336,1351,1372,1376,1424]',
#        'cn[1263,1275,1287,1303,1309,1335-1336,1351,1372,1376]',
#        'cn[1263,1275,1287,1303,1309,1335-1336,1351,1372-1373]',
#        'cn[1263,1275,1287,1303,1309,1335-1336,1348,1372-1373]',
#        'cn[1274-1277,1303-1321,1345-1354,1420-1427]', 'cn[1442,1444]',
#        'cn[1301,1382]', 'cn469', 'cn1446', 'cn1431', 'cn1212',
#        'cn[1356,1379]', 'cn1273', 'cn[1332-1334]',
#        'cn[1458,1464,1531-1533]', 'cn[1431-1432,1440-1442]',
#        'cn[1437,1530-1531]', 'cn1471', 'cn1301', 'cn[1421-1422]',
#        'cn[1270,1310]', 'cn[1291,1394]', 'cn1090',
#        'cn[305,308-309,311-314,318-320,322,324,326-329,332,334-338,340,347,349-356,360,365,369,372-374,380,385-390,392-393,395,405,407,409-410,413,415-416,418,420,427,429,435,437-441,444,450-451,453-458,467-468,483-488,494-497,1260-1261,1266-1267,1276-1277,1284-1286,1290-1292,1303-1318,1320-1321,1332-1333,1335-1336,1345-1346,1348-1350,1352-1353,1374-1377,1388-1391,1396-1397,1420-1421,1423-1426]',
# cn[1263,1275,1287,1303,1309,1335-1336,1351,1372,1376]    1
# Name: NODELIST, Length: 339, dtype: int64

# %%
# for gut-check, find most common values for failed nodelist.  
def find_most_common_values(df,column):
    return df[column].value_counts(ascending=False).iloc[0:30]

# %%
# not useful because it groups nodes 
find_most_common_values(failed, 'NODELIST')
# Out:
# cn1273           9
# cn1458           6
# cn1364           6
# cn304            6
# cn1270           5
# cn[1530-1531]    5
# cn1479           5
# cn1450           5
# cn1448           4
# cn1436           4
# cn1449           4
# cn1275           4
# cn1278           4
# cn[1468-1469]    4
# cn[1284-1286]    4
# cn1267           4
# cn[1297-1298]    3
# cn1387           3
# cn[1505-1506]    3
# cn1462           3
# cn382            3
# cn1445           3
# cn1313           3
# cn1261           3
# cn[1421-1422]    3
# cn1532           3
# cn[1343-1344]    3
# cn[1422-1423]    3
# cn[411-412]      3
# cn1258           3
# Name: NODELIST, dtype: int64

# %% [markdown]
# This is the code to separate out the nodelist.

# %%
#Separate out node list
#failed = accre df filtered to state = failed, partition = production 
nodelist = failed['NODELIST'].tolist()
nodelist_nums = [i.strip('cn').strip('[').strip(']') for i in nodelist if ',' not in i]
nodelist_commas = [i.strip('cn').strip('[').strip(']').split(',') for i in nodelist if ',' in i]

# %%
nodelist_commas = [item for sublist in nodelist_commas for item in sublist]

# %%
new_list = nodelist_commas + nodelist_nums

# %%
node_counts = {}
for n in new_list:
    if '-' in n:
        nodes = n.split('-')
        low, high = int(nodes[0]), int(nodes[1])
        for r in range (low, high + 1):
            if r not in node_counts:
                node_counts[r] = 1
            else: 
                node_counts[r] += 1
    else:
        r = int(n)
        if r not in node_counts:
            node_counts[r] = 1
        else: 
            node_counts[r] += 1

# %%
node_counts
# Out:
# {336: 16,
#  337: 14,
#  338: 17,
#  340: 22,
#  347: 24,
#  348: 14,
#  374: 25,
#  375: 14,
#  376: 16,
#  377: 15,
#  378: 12,
#  379: 14,
#  380: 13,
#  386: 22,
#  387: 19,
#  388: 19,
#  389: 17,
#  390: 20,
#  391: 19,
#  392: 21,
#  393: 18,
#  394: 8,
#  395: 18,
#  396: 13,
#  401: 19,
#  403: 20,
#  404: 19,
#  405: 19,
#  407: 17,
#  408: 16,
#  409: 4,
#  410: 23,
#  411: 23,
#  487: 18,
#  488: 13,
#  489: 9,
#  490: 13,
#  491: 20,
#  492: 23,
#  493: 18,
#  494: 21,
#  495: 20,
#  496: 25,
#  497: 21,
#  498: 8,
#  499: 17,
#  500: 13,
#  911: 6,
#  912: 8,
#  913: 5,
#  1081: 4,
#  326: 17,
#  331: 19,
#  332: 22,
#  333: 12,
#  334: 21,
#  335: 18,
#  349: 13,
#  361: 14,
#  362: 13,
#  363: 9,
#  364: 9,
#  365: 16,
#  366: 6,
#  367: 12,
#  398: 18,
#  399: 19,
#  400: 21,
#  412: 14,
#  413: 16,
#  414: 10,
#  441: 17,
#  442: 15,
#  443: 17,
#  444: 20,
#  445: 13,
#  446: 16,
#  447: 9,
#  448: 10,
#  464: 7,
#  465: 14,
#  466: 11,
#  467: 20,
#  468: 20,
#  469: 10,
#  470: 15,
#  471: 20,
#  472: 19,
#  473: 13,
#  1273: 15,
#  1274: 10,
#  1275: 18,
#  1276: 16,
#  1277: 13,
#  1278: 15,
#  1279: 9,
#  1340: 11,
#  1341: 13,
#  1342: 7,
#  1343: 13,
#  1344: 10,
#  1345: 13,
#  1263: 11,
#  1303: 11,
#  1309: 19,
#  1335: 18,
#  1336: 15,
#  1351: 17,
#  1372: 10,
#  1376: 21,
#  1424: 26,
#  1287: 9,
#  1373: 7,
#  1348: 14,
#  1304: 11,
#  1305: 14,
#  1306: 17,
#  1307: 15,
#  1308: 12,
#  1310: 21,
#  1311: 17,
#  1312: 14,
#  1313: 19,
#  1314: 17,
#  1315: 10,
#  1316: 13,
#  1317: 17,
#  1318: 13,
#  1319: 16,
#  1320: 16,
#  1321: 11,
#  1346: 13,
#  1347: 10,
#  1349: 14,
#  1350: 11,
#  1352: 20,
#  1353: 20,
#  1354: 13,
#  1420: 16,
#  1421: 23,
#  1422: 26,
#  1423: 27,
#  1425: 17,
#  1426: 22,
#  1427: 14,
#  1442: 14,
#  1444: 10,
#  1301: 8,
#  1382: 2,
#  1356: 7,
#  1379: 2,
#  1458: 16,
#  1464: 13,
#  1531: 13,
#  1532: 10,
#  1533: 10,
#  1431: 4,
#  1432: 8,
#  1440: 12,
#  1441: 11,
#  1437: 19,
#  1530: 12,
#  1270: 15,
#  1291: 12,
#  1394: 13,
#  305: 18,
#  308: 11,
#  309: 7,
#  311: 13,
#  312: 14,
#  313: 21,
#  314: 17,
#  318: 19,
#  319: 28,
#  320: 28,
#  322: 16,
#  324: 16,
#  327: 12,
#  328: 19,
#  329: 13,
#  350: 12,
#  351: 12,
#  352: 14,
#  353: 12,
#  354: 14,
#  355: 17,
#  356: 21,
#  360: 14,
#  369: 10,
#  372: 15,
#  373: 20,
#  385: 10,
#  415: 13,
#  416: 7,
#  418: 12,
#  420: 12,
#  427: 20,
#  429: 12,
#  435: 15,
#  437: 19,
#  438: 15,
#  439: 10,
#  440: 19,
#  450: 14,
#  451: 21,
#  453: 17,
#  454: 19,
#  455: 15,
#  456: 12,
#  457: 16,
#  458: 7,
#  483: 16,
#  484: 15,
#  485: 12,
#  486: 13,
#  1260: 9,
#  1261: 11,
#  1266: 8,
#  1267: 16,
#  1284: 21,
#  1285: 17,
#  1286: 13,
#  1290: 10,
#  1292: 8,
#  1332: 13,
#  1333: 10,
#  1374: 10,
#  1375: 13,
#  1377: 14,
#  1388: 13,
#  1389: 14,
#  1390: 10,
#  1391: 19,
#  1396: 20,
#  1397: 15,
#  316: 17,
#  423: 2,
#  432: 20,
#  1091: 17,
#  1127: 8,
#  1268: 9,
#  317: 14,
#  323: 14,
#  358: 12,
#  384: 15,
#  419: 11,
#  424: 4,
#  428: 8,
#  431: 15,
#  436: 11,
#  459: 11,
#  460: 9,
#  477: 16,
#  480: 13,
#  1334: 10,
#  1392: 18,
#  1368: 10,
#  1369: 10,
#  383: 3,
#  449: 7,
#  1084: 4,
#  1092: 7,
#  1093: 5,
#  1094: 7,
#  1258: 7,
#  1367: 8,
#  1494: 8,
#  1503: 3,
#  1504: 5,
#  1508: 6,
#  1486: 2,
#  1516: 8,
#  1517: 6,
#  1518: 6,
#  307: 9,
#  315: 14,
#  382: 6,
#  425: 3,
#  433: 17,
#  463: 9,
#  1087: 1,
#  1289: 10,
#  1338: 10,
#  1339: 15,
#  1398: 16,
#  1399: 14,
#  1130: 6,
#  1337: 16,
#  1448: 11,
#  1485: 3,
#  1446: 11,
#  1457: 12,
#  1326: 1,
#  1380: 5,
#  1085: 9,
#  1086: 7,
#  1088: 7,
#  1089: 10,
#  1122: 6,
#  1123: 8,
#  1269: 14,
#  1271: 9,
#  1443: 8,
#  1121: 8,
#  430: 4,
#  1090: 12,
#  1095: 7,
#  1082: 4,
#  1124: 6,
#  1203: 15,
#  1209: 15,
#  1217: 16,
#  1237: 12,
#  1240: 9,
#  1264: 5,
#  1281: 9,
#  1295: 7,
#  1296: 4,
#  1297: 9,
#  1299: 7,
#  1323: 10,
#  1324: 9,
#  1325: 10,
#  1330: 3,
#  1359: 11,
#  1370: 8,
#  1371: 8,
#  1378: 5,
#  1381: 3,
#  1385: 6,
#  1386: 7,
#  1438: 10,
#  1449: 12,
#  1471: 14,
#  1482: 5,
#  1493: 5,
#  1495: 8,
#  1496: 5,
#  1497: 7,
#  1498: 4,
#  1499: 8,
#  1500: 3,
#  1501: 5,
#  1502: 4,
#  1505: 5,
#  1506: 7,
#  1507: 3,
#  1520: 8,
#  1535: 5,
#  302: 10,
#  303: 13,
#  478: 11,
#  479: 13,
#  1393: 9,
#  1395: 17,
#  434: 16,
#  452: 16,
#  475: 12,
#  1207: 6,
#  1222: 7,
#  1227: 5,
#  1236: 10,
#  1241: 10,
#  1433: 13,
#  1434: 5,
#  1468: 19,
#  1469: 20,
#  1474: 16,
#  1475: 12,
#  368: 12,
#  370: 6,
#  1215: 16,
#  1216: 18,
#  1259: 6,
#  1514: 6,
#  1515: 8,
#  1519: 4,
#  1521: 7,
#  1522: 4,
#  1239: 15,
#  1272: 5,
#  1282: 8,
#  1327: 6,
#  1355: 11,
#  1358: 10,
#  1363: 6,
#  1383: 7,
#  1384: 6,
#  1436: 16,
#  1472: 16,
#  1473: 13,
#  1361: 5,
#  330: 12,
#  357: 11,
#  482: 14,
#  1509: 2,
#  417: 4,
#  1205: 11,
#  1208: 8,
#  1212: 13,
#  1463: 7,
#  1465: 11,
#  1466: 10,
#  306: 8,
#  1131: 4,
#  1331: 8,
#  359: 7,
#  1288: 4,
#  1470: 7,
#  1492: 4,
#  1481: 9,
#  1439: 14,
#  1459: 10,
#  1479: 17,
#  1293: 5,
#  1328: 6,
#  1362: 4,
#  1366: 4,
#  1233: 11,
#  1455: 9,
#  1230: 8,
#  1128: 8,
#  1235: 14,
#  474: 10,
#  1125: 5,
#  1126: 6,
#  1132: 5,
#  1133: 2,
#  1202: 15,
#  1210: 7,
#  1234: 12,
#  1242: 5,
#  1257: 4,
#  1430: 9,
#  1445: 11,
#  1452: 7,
#  1467: 8,
#  1477: 7,
#  1480: 7,
#  1201: 11,
#  1232: 9,
#  1454: 12,
#  1360: 3,
#  1213: 12,
#  1214: 14,
#  1218: 10,
#  1225: 15,
#  1226: 8,
#  1229: 10,
#  1211: 1,
#  1219: 11,
#  1096: 5,
#  481: 8,
#  1204: 8,
#  1221: 12,
#  1224: 13,
#  1228: 6,
#  1238: 8,
#  1265: 5,
#  1294: 7,
#  1322: 4,
#  1364: 11,
#  1435: 10,
#  1460: 9,
#  1461: 11,
#  476: 9,
#  1206: 11,
#  1220: 12,
#  1223: 10,
#  1447: 4,
#  1450: 11,
#  1451: 7,
#  1462: 13,
#  1476: 12,
#  1280: 4,
#  1283: 4,
#  1298: 7,
#  1300: 4,
#  1302: 3,
#  1329: 3,
#  1365: 4,
#  1484: 2,
#  1487: 3,
#  1488: 1,
#  1490: 1,
#  1513: 3,
#  1523: 5,
#  1526: 3,
#  1527: 2,
#  1529: 1,
#  1387: 7,
#  1129: 5,
#  304: 8,
#  1083: 4,
#  1357: 4,
#  1512: 2,
#  1524: 3,
#  1262: 3,
#  1534: 2,
#  1536: 4,
#  1135: 2,
#  1453: 5,
#  1400: 1,
#  1483: 2,
#  1491: 1,
#  461: 1,
#  421: 1}

# %%
node_counts_sep = pd.DataFrame.from_dict(node_counts, orient = 'index')
node_counts_sep.head()
# Out:
#       0
# 336  16
# 337  14
# 338  17
# 340  22
# 347  24

# %%
# node_counts_sep.sort_values(by=['0'])

# %%
# unable to change column name from '0' to 'count', so converted to csv above and will bring back in
# col={'index': 'nodes', '0': 'count'}
# node_counts_sep=node_counts_sep.rename(columns=col)
# node_counts_sep.head()

# %%
# convert node_counts_sep to csv to create visualization called 'failed_notes' 
node_counts_sep = node_counts_sep.reset_index()
node_counts_sep.to_csv('../data/failed_notes.csv', index = False)
# changed column names in data from 'nodes', '0' to 'node_name', 'count'

# %%
failed_visual = pd.read_csv('../data/failed_notes.csv')
failed_visual.head(15)
# Out:
#     index   0
# 0     336  16
# 1     337  14
# 2     338  17
# 3     340  22
# 4     347  24
# 5     348  14
# 6     374  25
# 7     375  14
# 8     376  16
# 9     377  15
# 10    378  12
# 11    379  14
# 12    380  13
# 13    386  22
# 14    387  19

# %%
failed_visual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   507 non-null    int64
#  1   0       507 non-null    int64
# dtypes: int64(2)
# memory usage: 8.0 KB

# %% [markdown]
# 507 unique nodes.  I converted the file to an Excel and sorted there.  Will attempt to sort the node number by their values here.

# %%
# not working
#failed_visual.groupby('node_name')['node_name'].count().sort_values()

# %%
# Worked, now it does not
#failed_visual = failed_visual['count'].hist(bins = 25);

# %%
# sns.scatterplot(data = failed_visual, x = 'nodes', y = 'count', hue = 'origin');

# %%
#alternative would be to use regex
#impor re
#nn = [re.strip(‘cn|\[|\]’, i)]

# %%
#alternative 
#range_ = list(range(low, high+1))

# %%
#alternative
#node_counts[r] + node_counts[r] + 1
